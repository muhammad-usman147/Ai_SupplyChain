# %% [markdown]
# ### Creating DataSet For Supply Chain Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
apr = pd.read_csv("PK COVID-19-30apr.csv")
apr
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 0     2/26/2020      1       0          0                   China
# 1     2/26/2020      2       0          0             Iran/Taftan
# 2     2/29/2020      1       0          0                   China
# 3     2/29/2020      1       0          0             Iran/Taftan
# 4      3/2/2020      1       0          0             Iran/Taftan
# ...         ...    ...     ...        ...                     ...
# 1151  4/30/2020     34       0          0  Local - Social Contact
# 1152  4/30/2020      2       0          0  Local - Social Contact
# 1153  4/30/2020     75       0          0  Local - Social Contact
# 1154  4/30/2020      6       0          0  Local - Social Contact
# 1155  4/30/2020      1       0          0  Local - Social Contact
#
#                          Province          City
# 0     Islamabad Capital Territory     Islamabad
# 1                           Sindh       Karachi
# ...

# %%
may = pd.read_csv("PK COVID-19-10may.csv")
may
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 0     2/26/2020      1       0          0                   China
# 1     2/26/2020      2       0          0             Iran/Taftan
# 2     2/29/2020      1       0          0                   China
# 3     2/29/2020      1       0          0             Iran/Taftan
# 4      3/2/2020      1       0          0             Iran/Taftan
# ...         ...    ...     ...        ...                     ...
# 1323  5/10/2020    709       8         29  Local - Social Contact
# 1324  5/10/2020     59       0          0  Local - Social Contact
# 1325  5/10/2020     12       0          1  Local - Social Contact
# 1326  5/10/2020    160      11         40  Local - Social Contact
# 1327  5/10/2020      7       0          0  Local - Social Contact
#
#                          Province          City
# 0     Islamabad Capital Territory     Islamabad
# 1                           Sindh       Karachi
# ...

# %%
june = pd.read_csv("PK COVID-19-3jun.csv")
june
# Out:
#            Date  Cases  Deaths  Recovered Travel_history  \
# 0     2/26/2020      1       0          0          China
# 1     2/26/2020      2       0          0    Iran/Taftan
# 2     2/29/2020      1       0          0          China
# 3     2/29/2020      1       0          0    Iran/Taftan
# 4      3/2/2020      1       0          0    Iran/Taftan
# ...         ...    ...     ...        ...            ...
# 2793  5/30/2020    952      36        394            NaN
# 2794  5/31/2020   1184      22        120            NaN
# 2795   6/1/2020   1610      43         95            NaN
# 2796   6/2/2020   1639      30        353            NaN
# 2797   6/3/2020   1615      37        243            NaN
#
#                          Province       City
# 0     Islamabad Capital Territory  Islamabad
# 1                           Sindh    Karachi
# 2     Islamabad Capital Territory  Islamabad
# 3                           Sindh    Karachi
# 4                Gilgit-Baltistan     Gilgit
# ...

# %%
pd.concat([apr,may])
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 0     2/26/2020      1       0          0                   China
# 1     2/26/2020      2       0          0             Iran/Taftan
# 2     2/29/2020      1       0          0                   China
# 3     2/29/2020      1       0          0             Iran/Taftan
# 4      3/2/2020      1       0          0             Iran/Taftan
# ...         ...    ...     ...        ...                     ...
# 1323  5/10/2020    709       8         29  Local - Social Contact
# 1324  5/10/2020     59       0          0  Local - Social Contact
# 1325  5/10/2020     12       0          1  Local - Social Contact
# 1326  5/10/2020    160      11         40  Local - Social Contact
# 1327  5/10/2020      7       0          0  Local - Social Contact
#
#                          Province          City
# 0     Islamabad Capital Territory     Islamabad
# 1                           Sindh       Karachi
# ...

# %%
df = pd.concat([pd.concat([apr,may]),june])
df
# Out:
#            Date  Cases  Deaths  Recovered Travel_history  \
# 0     2/26/2020      1       0          0          China
# 1     2/26/2020      2       0          0    Iran/Taftan
# 2     2/29/2020      1       0          0          China
# 3     2/29/2020      1       0          0    Iran/Taftan
# 4      3/2/2020      1       0          0    Iran/Taftan
# ...         ...    ...     ...        ...            ...
# 2793  5/30/2020    952      36        394            NaN
# 2794  5/31/2020   1184      22        120            NaN
# 2795   6/1/2020   1610      43         95            NaN
# 2796   6/2/2020   1639      30        353            NaN
# 2797   6/3/2020   1615      37        243            NaN
#
#                          Province       City
# 0     Islamabad Capital Territory  Islamabad
# 1                           Sindh    Karachi
# 2     Islamabad Capital Territory  Islamabad
# 3                           Sindh    Karachi
# 4                Gilgit-Baltistan     Gilgit
# ...

# %%
y = list(df['Cases'])

# %%
x = list(df['Date'])

# %%
figure = plt.figure(figsize=(20,10))
plt.xticks(rotation = 90)
sns.lineplot(x = x, y = y)

# %%
figure = plt.figure(figsize=(20,10))
plt.xticks(rotation = 90)
sns.barplot(x = x, y = y)

# %%
np.random.seed(8)
masks_sold = [np.random.randint(500,1000) for i in range(len(x))]

# %%
figure = plt.figure(figsize=(20,10))
plt.xticks(rotation = 90)
plt.title("Masks sold during Covid-19")
sns.lineplot(x = x, y = masks_sold)

# %%
np.random.seed(9)
sanitizers = [np.random.randint(500,5000) for i in range(len(x))]

# %%
figure = plt.figure(figsize=(20,10))
plt.xticks(rotation = 90)
plt.title("Sanitizers sold during Covid-19")
sns.lineplot(x = x, y = sanitizers)

# %% [markdown]
# ## <center> Artificial Intelligence and Supply Chain Management </center>

# %% [markdown]
# ### <center> Covid - 19, Impact on Masks and Sanitizers </center>

# %% [markdown]
# ### Adding Creating Datasets for Masks and Sanitizers

# %%
df['masks'] = masks_sold

# %%
df['sanitizers'] = sanitizers

# %%
df
# Out:
#            Date  Cases  Deaths  Recovered Travel_history  \
# 0     2/26/2020      1       0          0          China
# 1     2/26/2020      2       0          0    Iran/Taftan
# 2     2/29/2020      1       0          0          China
# 3     2/29/2020      1       0          0    Iran/Taftan
# 4      3/2/2020      1       0          0    Iran/Taftan
# ...         ...    ...     ...        ...            ...
# 2793  5/30/2020    952      36        394            NaN
# 2794  5/31/2020   1184      22        120            NaN
# 2795   6/1/2020   1610      43         95            NaN
# 2796   6/2/2020   1639      30        353            NaN
# 2797   6/3/2020   1615      37        243            NaN
#
#                          Province       City  masks  sanitizers
# 0     Islamabad Capital Territory  Islamabad    951         882
# 1                           Sindh    Karachi    840        4944
# 2     Islamabad Capital Territory  Islamabad    997        1001
# ...

# %%
df.to_csv("SupplyChain.csv",index = False)
